# %%
from google.colab import drive
import pandas as pd
import random

# %%
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
file_path = '/content/myntra (1).csv'
df = pd.read_csv(file_path)


post_types = ["Reels", "Videos", "Carousel Posts", "Static Images", "Stories","Polls", "Memes", "Infographics", "Product Showcases", "Live Streams"]


df['post_type'] = [random.choice(post_types) for i in range(len(df))]

# %%
df.head(3)
# Out:
#              profileURL                                       company logo  \
# 0  https://x.com/myntra  https://pbs.twimg.com/profile_images/161740779...
# 1  https://x.com/myntra  https://pbs.twimg.com/profile_images/161740779...
# 2  https://x.com/myntra  https://pbs.twimg.com/profile_images/161740779...
#
#   company name-discard  date of post  \
# 0               Myntra   Nov 9, 2024
# 1               Myntra  Nov 15, 2024
# 2               Myntra  Nov 11, 2024
#
#                                           caption -1  \
# 0  Bari barsi khatan gya se, wedding ka hai seaso...
# 1    She’s bringing the glam, the glow, and the wow!
# 2  From keeping it together to keeping it stylish...
#
#                                          caption - 2  \
# 0  Ace every beauty look this wedding season with...
# 1                                                NaN
# 2         Wearing @the_ethnic_company - Available on
#
# ...

# %%
df['views'] = df['views'].str.replace('K', '').astype(float) * 1000

# %%
output_path = '/content/drive/My Drive/Myntra_updated.csv'  # Update with your desired file name
df.to_csv(output_path, index=False)
